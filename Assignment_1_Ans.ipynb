# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# - *
# - 'hello'
# - 87.8
# - -
# - /
# - 6

# %%
""" 
* is Mathamatic Expression ie. Multiplication
"hello" is Value with String datatype.
87.8 is Value with float datatype.
- Mathamatic Expression ie. Substraction.
/ is Mathamatic Expression ie. Division.
6 is Value with integer datatype.
"""

# %% [markdown]
# 2.What is the difference between string and variable?
#
# => Sting is Datatype  where as in Variale we can store Values with Various datatype ie. integer, float, String, , Complex no etc.

# %% [markdown]
# 3.Describe three different data types.

# %%
A = 5          
B = "Swapnil"
C = 33.5
print(f"Variable A holds Value {A} with type{type(A)} datatype")
print(f"Variable B holds Value {B} with type{type(B)} datatype")
print(f"Variable A holds Value {C} with type{type(C)} datatype")
# Out:
# Variable A holds Value 5 with type<class 'int'> datatype
# Variable B holds Value Swapnil with type<class 'str'> datatype
# Variable A holds Value 33.5 with type<class 'float'> datatype

# %% [markdown]
# 4.What is an expression made up of? What do all expressions do?

# %%
"""
Expression is made up of Multiple Values operators,
Wxpression Evaluates to a single value in accordance with syntax.

"""

# %% [markdown]
# 5.This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %%
"""
Statement is used to print something to Assign some values to any variable,
where as Expression is something which is used to find some results
using some operators, Conditional statements etc.
"""
eg.

spam = 10  # is a statement
spam = 10 + 10 # is an expression

# %% [markdown]
# 6.After running the following code, what does the variable bacon contain?
#
# - bacon = 22
# - bacon + 1

# %%
baccon = 22
print(f"Before baccon+1 baccon = {baccon}")
baccon + 1
print(f"After baccon+1 baccon = {baccon}")
# Out:
# Before baccon+1 baccon = 22
# After baccon+1 baccon = 22

# %% [markdown]
# 7.What should the values of the following two terms be?
# - 'spam' + 'spamspam'
# - 'spam' * 3

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8.Why is eggs a valid variable name while 100 is invalid?
#
# =>
#    - eggs is Valid Variable name and 100 is invalid because
#    - 100 is a value and variable can't be a value
#    - also variables Can't start with Number

# %% [markdown]
# 9.What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
X = "10"
A = int(X)   # to get Integer Version of Value
B = float(X) # to get Float Version of Value
C = str(X)   # to get String Version of Value

print(f"Value {A} with {type(A)} Datatype ")
print(f"Value {B} with {type(B)} Datatype ")
print(f"Value {C} with {type(C)} Datatype ")
# Out:
# Value 10 with <class 'int'> Datatype
# Value 10.0 with <class 'float'> Datatype
# Value 10 with <class 'str'> Datatype

# %% [markdown]
# 10.Why does this expression cause an error? How can you fix it?
# - 'I have eaten ' + 99 + ' burritos.'

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %%
'I have eaten ' + '99' + ' burritos.'  # 99 is wirh integer datatype an we can't add or concate string & integer
                                       # 99 is treated as string by writing in side Single inverted comma ie. '' .
                                       # so that we can Add or concate Strings
# Out:
# 'I have eaten 99 burritos.'
